# %%
import os
import torch
import mmcv
import mmseg 
from mmengine.runner import Runner
import glob
import sys
import numpy

print(f"PyTorch 버전: {torch.__version__}")
print(f"CUDA 사용 가능 여부: {torch.cuda.is_available()}")
print(f"MMSegmentation 버전: {mmseg.__version__}")

config_file = './configs/segformer/segformer_mit-b5_8xb2-160k_ade20k-512x512.py'

work_dir = './work_dirs/segformer_mission3'
# Out:
# PyTorch 버전: 2.7.1+cu128
# CUDA 사용 가능 여부: True
# MMSegmentation 버전: 1.2.2

# %%
# !python3 preprocess_m.py
# Out:
# '../data/Mission3/Training/labels' 폴더의 파일을 변환합니다...
# 100%|██████████████████████████████████████| 8000/8000 [01:02<00:00, 127.88it/s]
# '../data/Mission3/Validation/labels' 폴더의 파일을 변환합니다...
# 100%|██████████████████████████████████████| 1000/1000 [00:07<00:00, 128.39it/s]

# %%
from mmengine.config import Config

cfg = Config.fromfile(config_file)

# env_cfg 부분을 재현성에 맞게 수정
cfg.env_cfg = dict(
    cudnn_benchmark=False,  # 재현성을 위해 False로 변경
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
    dist_cfg=dict(backend='nccl'),
    seed=500,
    deterministic=True)     # 결정적 동작을 위한 옵션 추가

# 수정된 내용을 다시 파일에 저장
cfg.dump(config_file)

print(f"'{config_file}'의 시드 설정이 완료되었습니다.")
print("수정된 내용:")
print(cfg.env_cfg)
# Out:
# './configs/segformer/segformer_mit-b5_8xb2-160k_ade20k-512x512.py'의 시드 설정이 완료되었습니다.
# 수정된 내용:
# {'cudnn_benchmark': False, 'mp_cfg': {'mp_start_method': 'fork', 'opencv_num_threads': 0}, 'dist_cfg': {'backend': 'nccl'}, 'seed': 500, 'deterministic': True}

# %%
# !python3 tools/train.py {config_file} --work-dir {work_dir}

print("\n--- 학습이 완료되었습니다. ---")
print(f"학습 결과 및 체크포인트는 '{work_dir}' 폴더를 확인하세요.")
# Out:
# 10/12 22:37:02 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.13 (main, Jun  5 2025, 13:12:00) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 539689079
#     GPU 0: NVIDIA GeForce RTX 5080
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.8, V12.8.61
#     GCC: gcc (Ubuntu 12.3.0-1ubuntu1~22.04.2) 12.3.0
#     PyTorch: 2.8.0+cu128
#     PyTorch compiling details: PyTorch built with:
#   - GCC 13.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.7.1 (Git Hash 8d263e693366ef8db40acc569cc7d8edf644556d)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.8
#   - NVCC architecture flags: -gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_100,code=sm_100;-gencode;arch=compute_120,code=sm_120
#   - CuDNN 91.0.2  (built against CUDA 12.9)
#     - Built with CuDNN 90.8
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=a1cb3cc05d46d198467bebbb6e8fba50a325d4e7, CUDA_VERSION=12.8, CUDNN_VERSION=9.8.0, CXX_COMPILER=/opt/rh/gcc-toolset-13/root/usr/bin/c++, CXX_FLAGS= -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -DC10_NODEPRECATED -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -faligned-new -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-dangling-reference -Wno-error=dangling-reference -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.8.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF, USE_XCCL=OFF, USE_XPU=OFF,
#
#     TorchVision: 0.23.0+cu128
#     OpenCV: 4.12.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     deterministic: True
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 539689079
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 10/12 22:37:02 - mmengine - INFO - Config:
# checkpoint = '/home/ase/Desktop/mmsegmentation/work_dirs/segformer_mission3/iter_104000.pth'
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=0,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/home/ase/K-ICT/data/Mission3/'
# dataset_type = 'CustomDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False, interval=4000, save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, interval=4000, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     deterministic=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     seed=500)
# launcher = 'none'
# load_from = '/home/ase/Desktop/mmsegmentation/work_dirs/segformer_mission3/iter_104000.pth'
# log_level = 'INFO'
# metainfo = dict(classes=[
#     'background',
#     'factoryground',
# ])
# model = dict(
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=64,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint=
#             '/home/ase/Desktop/mmsegmentation/work_dirs/segformer_mission3/iter_104000.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             3,
#             6,
#             40,
#             3,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=0,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=256,
#         dropout_ratio=0.1,
#         in_channels=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             class_weight=1.5,
#             loss_weight=1.0,
#             type='CrossEntropyLoss',
#             use_sigmoid=True),
#         num_classes=1,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=160000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Validation/images',
#             seg_map_path='Validation/labels_remapped'),
#         data_root='/home/ase/K-ICT/data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 512,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         2048,
#         512,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(
#     max_iters=120000, type='IterBasedTrainLoop', val_interval=4000)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Training/images',
#             seg_map_path='Training/labels_remapped'),
#         data_root='/home/ase/K-ICT/data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     2048,
#                     512,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(degree=15, prob=0.5, type='RandomRotate'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             2048,
#             512,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(degree=15, prob=0.5, type='RandomRotate'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Validation/images',
#             seg_map_path='Validation/labels_remapped'),
#         data_root='/home/ase/K-ICT/data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 512,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmseg.SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/segformer_mission3'
#
# /home/ase/Desktop/mmsegmentation/mmseg/models/decode_heads/decode_head.py:136: UserWarning: threshold is not defined for binary, and defaultsto 0.3
#   warnings.warn('threshold is not defined for binary, and defaults'
# /home/ase/Desktop/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 10/12 22:37:03 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 10/12 22:37:03 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:weight_decay=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:decay_mult=0.0
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.bias:lr=6e-05
# 10/12 22:37:03 - mmengine - INFO - paramwise_options -- backbone.layers.2.1
time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:05:48 - mmengine - INFO - Epoch(val) [0][ 100/1000]    eta: 0:00:22  time: 0.0212  data_time: 0.0036  memory: 1134
# 10/13 04:05:49 - mmengine - INFO - Epoch(val) [0][ 150/1000]    eta: 0:00:20  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:05:50 - mmengine - INFO - Epoch(val) [0][ 200/1000]    eta: 0:00:18  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:05:51 - mmengine - INFO - Epoch(val) [0][ 250/1000]    eta: 0:00:17  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:05:53 - mmengine - INFO - Epoch(val) [0][ 300/1000]    eta: 0:00:15  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:05:54 - mmengine - INFO - Epoch(val) [0][ 350/1000]    eta: 0:00:14  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:05:55 - mmengine - INFO - Epoch(val) [0][ 400/1000]    eta: 0:00:13  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:05:56 - mmengine - INFO - Epoch(val) [0][ 450/1000]    eta: 0:00:12  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:05:57 - mmengine - INFO - Epoch(val) [0][ 500/1000]    eta: 0:00:10  time: 0.0211  data_time: 0.0035  memory: 1134
# 10/13 04:05:58 - mmengine - INFO - Epoch(val) [0][ 550/1000]    eta: 0:00:09  time: 0.0212  data_time: 0.0036  memory: 1134
# 10/13 04:05:59 - mmengine - INFO - Epoch(val) [0][ 600/1000]    eta: 0:00:08  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:06:00 - mmengine - INFO - Epoch(val) [0][ 650/1000]    eta: 0:00:07  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:06:01 - mmengine - INFO - Epoch(val) [0][ 700/1000]    eta: 0:00:06  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:06:02 - mmengine - INFO - Epoch(val) [0][ 750/1000]    eta: 0:00:05  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:06:03 - mmengine - INFO - Epoch(val) [0][ 800/1000]    eta: 0:00:04  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:06:04 - mmengine - INFO - Epoch(val) [0][ 850/1000]    eta: 0:00:03  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:06:05 - mmengine - INFO - Epoch(val) [0][ 900/1000]    eta: 0:00:02  time: 0.0210  data_time: 0.0036  memory: 1134
# 10/13 04:06:06 - mmengine - INFO - Epoch(val) [0][ 950/1000]    eta: 0:00:01  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:06:07 - mmengine - INFO - Epoch(val) [0][1000/1000]    eta: 0:00:00  time: 0.0211  data_time: 0.0036  memory: 1134
# 10/13 04:06:07 - mmengine - INFO - per class results:
# 10/13 04:06:07 - mmengine - INFO -
# +---------------+-------+-------+
# |     Class     |  IoU  |  Acc  |
# +---------------+-------+-------+
# |   background  | 98.21 | 98.51 |
# | factoryground | 91.96 | 98.53 |
# +---------------+-------+-------+
# 10/13 04:06:07 - mmengine - INFO - Epoch(val) [0][1000/1000]    aAcc: 98.5100  mIoU: 95.0900  mAcc: 98.5200  data_time: 0.0040  time: 0.0215
#
# --- 학습이 완료되었습니다. ---
# 학습 결과 및 체크포인트는 './work_dirs/segformer_mission3' 폴더를 확인하세요.

# %%
sys.modules['numpy._core'] = numpy
sys.modules['numpy._core.multiarray'] = numpy.core.multiarray

print(f"--- '{work_dir}' 폴더에서 Best 체크포인트를 찾습니다... ---")

best_checkpoint_list = glob.glob(os.path.join(work_dir, 'best_*.pth'))

if not best_checkpoint_list:
    print(f"!!! 에러: '{work_dir}' 폴더에서 Best 체크포인트 파일을 찾을 수 없습니다.")
else:
    best_checkpoint_path = best_checkpoint_list[0]
    print(f"성공적으로 파일을 찾았습니다: {best_checkpoint_path}")

    src = best_checkpoint_path
    dst = os.path.splitext(src)[0] + ".weights_only.pth"

    print(f"\n--- 가중치만 추출하여 변환을 시작합니다... ---")
    
    ckpt = torch.load(src, map_location="cpu", weights_only=False)
    state = ckpt.get("state_dict", ckpt)
    torch.save(state, dst)

    weights_only_path = dst
    print(f"\n 변환 완료! 가중치 파일이 저장되었습니다: {weights_only_path}")
# Out:
# --- './work_dirs/segformer_mission3' 폴더에서 Best 체크포인트를 찾습니다... ---
# 성공적으로 파일을 찾았습니다: ./work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.pth
#
# --- 가중치만 추출하여 변환을 시작합니다... ---
#
#  변환 완료! 가중치 파일이 저장되었습니다: ./work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.weights_only.pth

# %%
checkpoint_paths = glob.glob(os.path.join(work_dir, 'best_*only.pth'))

if not checkpoint_paths:
    raise FileNotFoundError(f"{work_dir} 에서 best checkpoint 파일을 찾을 수 없습니다.")

best_checkpoint = max(checkpoint_paths, key=os.path.getmtime)

print(f"선택된 best checkpoint 파일: {best_checkpoint}")

# !python tools/test.py {config_file} {best_checkpoint} --cfg-options resume=False resume_from=None auto_resume=False

print("\n--- 평가가 완료되었습니다. ---")
# Out:
# 선택된 best checkpoint 파일: ./work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.pth
# 10/14 20:49:25 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.0 (default, Mar  3 2022, 09:58:08) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1317409557
#     GPU 0: NVIDIA GeForce RTX 5080
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.8, V12.8.61
#     GCC: gcc (Ubuntu 12.3.0-1ubuntu1~22.04.2) 12.3.0
#     PyTorch: 2.7.1+cu128
#     PyTorch compiling details: PyTorch built with:
#   - GCC 11.2
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.7.1 (Git Hash 8d263e693366ef8db40acc569cc7d8edf644556d)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.8
#   - NVCC architecture flags: -gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_100,code=sm_100;-gencode;arch=compute_120,code=sm_120;-gencode;arch=compute_120,code=compute_120
#   - CuDNN 90.7.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=e2d141dbde55c2a4370fac5165b0561b6af4798b, CUDA_VERSION=12.8, CUDNN_VERSION=9.7.1, CXX_COMPILER=/opt/rh/gcc-toolset-11/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=1 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.7.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.22.1+cu128
#     OpenCV: 4.12.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     deterministic: True
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1317409557
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 10/14 20:49:25 - mmengine - INFO - Config:
# auto_resume = False
# checkpoint = './work_dirs/segformer_mission3/best_mIoU_iter_108000.pth'
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=0,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '../data/Mission3/'
# dataset_type = 'CustomDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False, interval=4000, save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, interval=4000, type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     deterministic=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     seed=500)
# launcher = 'none'
# load_from = './work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.pth'
# log_level = 'INFO'
# metainfo = dict(classes=[
#     'background',
#     'factoryground',
# ])
# model = dict(
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=64,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint=
#             './work_dirs/segformer_mission3/best_mIoU_iter_108000.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             3,
#             6,
#             40,
#             3,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=0,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=256,
#         dropout_ratio=0.1,
#         in_channels=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             class_weight=1.5,
#             loss_weight=1.0,
#             type='CrossEntropyLoss',
#             use_sigmoid=True),
#         num_classes=1,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=160000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# resume_from = None
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Validation/images',
#             seg_map_path='Validation/labels_remapped'),
#         data_root='../data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 512,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         2048,
#         512,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(
#     max_iters=120000, type='IterBasedTrainLoop', val_interval=4000)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Training/images',
#             seg_map_path='Training/labels_remapped'),
#         data_root='../data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     2048,
#                     512,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(degree=15, prob=0.5, type='RandomRotate'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             2048,
#             512,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(degree=15, prob=0.5, type='RandomRotate'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='Validation/images',
#             seg_map_path='Validation/labels_remapped'),
#         data_root='../data/Mission3/',
#         img_suffix='.tif',
#         metainfo=dict(classes=[
#             'background',
#             'factoryground',
#         ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 512,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.tif',
#         type='CustomDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='mmseg.SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/segformer_mit-b5_8xb2-160k_ade20k-512x512'
#
# /home/ase/K-ICT/Mission3/mmseg/models/decode_heads/decode_head.py:136: UserWarning: threshold is not defined for binary, and defaultsto 0.3
#   warnings.warn('threshold is not defined for binary, and defaults'
# /home/ase/K-ICT/Mission3/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 10/14 20:49:26 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 10/14 20:49:26 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 10/14 20:49:26 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by local backend from path: ./work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.pth
# 10/14 20:49:27 - mmengine - INFO - Load checkpoint from ./work_dirs/segformer_mission3/best_mIoU_iter_108000.weights_only.pth
# 10/14 20:49:54 - mmengine - INFO - Epoch(test) [  50/1000]    eta: 0:08:21  time: 0.5396  data_time: 0.5191  memory: 482
# 10/14 20:50:20 - mmengine - INFO - Epoch(test) [ 100/1000]    eta: 0:07:53  time: 0.5248  data_time: 0.5048  memory: 482
# 10/14 20:50:47 - mmengine - INFO - Epoch(test) [ 150/1000]    eta: 0:07:30  time: 0.5561  data_time: 0.5361  memory: 482
# 10/14 20:51:14 - mmengine - INFO - Epoch(test) [ 200/1000]    eta: 0:07:05  time: 0.5267  data_time: 0.5067  memory: 482
# 10/14 20:51:41 - mmengine - INFO - Epoch(test) [ 250/1000]    eta: 0:06:41  time: 0.5530  data_time: 0.5320  memory: 482
# 10/14 20:52:08 - mmengine - INFO - Epoch(test) [ 300/1000]    eta: 0:06:14  time: 0.5336  data_time: 0.5130  memory: 482
# 10/14 20:52:35 - mmengine - INFO - Epoch(test) [ 350/1000]    eta: 0:05:48  time: 0.5409  data_time: 0.5213  memory: 482
# 10/14 20:53:01 - mmengine - INFO - Epoch(test) [ 400/1000]    eta: 0:05:21  time: 0.5212  data_time: 0.5015  memory: 482
# 10/14 20:53:28 - mmengine - INFO - Epoch(test) [ 450/1000]    eta: 0:04:54  time: 0.5218  data_time: 0.5022  memory: 482
# 10/14 20:53:54 - mmengine - INFO - Epoch(test) [ 500/1000]    eta: 0:04:27  time: 0.5451  data_time: 0.5255  memory: 482
# 10/14 20:54:21 - mmengine - INFO - Epoch(test) [ 550/1000]    eta: 0:04:00  time: 0.5243  data_time: 0.5045  memory: 482
# 10/14 20:54:48 - mmengine - INFO - Epoch(test) [ 600/1000]    eta: 0:03:33  time: 0.5118  data_time: 0.4919  memory: 482
# 10/14 20:55:14 - mmengine - INFO - Epoch(test) [ 650/1000]    eta: 0:03:07  time: 0.5785  data_time: 0.5584  memory: 482
# 10/14 20:55:41 - mmengine - INFO - Epoch(test) [ 700/1000]    eta: 0:02:40  time: 0.5580  data_time: 0.5383  memory: 482
# 10/14 20:56:07 - mmengine - INFO - Epoch(test) [ 750/1000]    eta: 0:02:13  time: 0.5236  data_time: 0.5039  memory: 482
# 10/14 20:56:34 - mmengine - INFO - Epoch(test) [ 800/1000]    eta: 0:01:46  time: 0.5391  data_time: 0.5189  memory: 482
# 10/14 20:57:01 - mmengine - INFO - Epoch(test) [ 850/1000]    eta: 0:01:20  time: 0.5357  data_time: 0.5152  memory: 482
# 10/14 20:57:28 - mmengine - INFO - Epoch(test) [ 900/1000]    eta: 0:00:53  time: 0.5157  data_time: 0.4960  memory: 482
# 10/14 20:57:54 - mmengine - INFO - Epoch(test) [ 950/1000]    eta: 0:00:26  time: 0.5151  data_time: 0.4950  memory: 482
# 10/14 20:58:21 - mmengine - INFO - Epoch(test) [1000/1000]    eta: 0:00:00  time: 0.5057  data_time: 0.4859  memory: 482
# 10/14 20:58:21 - mmengine - INFO - per class results:
# 10/14 20:58:21 - mmengine - INFO -
# +---------------+-------+-------+
# |     Class     |  IoU  |  Acc  |
# +---------------+-------+-------+
# |   background  | 98.24 | 98.58 |
# | factoryground | 92.07 | 98.33 |
# +---------------+-------+-------+
# 10/14 20:58:21 - mmengine - INFO - Epoch(test) [1000/1000]    aAcc: 98.5400  mIoU: 95.1500  mAcc: 98.4500  data_time: 0.5131  time: 0.5334
#
# --- 평가가 완료되었습니다. ---
